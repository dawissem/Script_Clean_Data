# %%
#********************************************************************************************#
#******************************************FROM HERE ****************************************#
#********************************************************************************************#

# %%
# !pip install python-pptx

from google.colab import drive
from pptx import Presentation
import re
import random
# Out:
# Requirement already satisfied: python-pptx in /usr/local/lib/python3.11/dist-packages (1.0.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (11.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (3.2.3)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (5.3.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (4.12.2)

# %%
# 📌 Étape 1 : Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 📌 Étape 2 : Installer les bibliothèques nécessaires
# !pip install python-pptx pandas

# 📌 Étape 3 : Extraire les chunks depuis le PowerPoint
from pptx import Presentation
import pandas as pd
import re

def clean_text(text):
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'^\d+[\.\)-]?', '', text)
    return text.strip()

def extract_pptx_chunks(file_path):
    prs = Presentation(file_path)
    chunks = []

    for i, slide in enumerate(prs.slides):
        texts = []
        for shape in slide.shapes:
            if hasattr(shape, "text"):
                text = clean_text(shape.text)
                if text:
                    texts.append(text)
        full_text = " ".join(texts)
        if full_text:
            chunks.append({
                "slide_num": i + 1,
                "text": full_text
            })

    return pd.DataFrame(chunks)

# 📂 Ton fichier PPTX
file_path = "/content/drive/MyDrive/BASE DE CONNAISSANCES/TW-Formation Métiers.pptx"

# 🧾 Extraction
df_chunks = extract_pptx_chunks(file_path)

# 💾 Sauvegarde
df_chunks.to_csv("/content/drive/MyDrive/BASE DE CONNAISSANCES/chunks_TW.csv", index=False)
df_chunks.to_json("/content/drive/MyDrive/BASE DE CONNAISSANCES/chunks_TW.json", orient="records", indent=2)

# ✅ Confirmation
print("✅ Extraction terminée. Fichier enregistré dans Google Drive.")
# Out:
# Mounted at /content/drive
# Requirement already satisfied: python-pptx in /usr/local/lib/python3.11/dist-packages (1.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (11.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (3.2.3)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (5.3.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (4.12.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ✅ Extraction terminée. Fichier enregistré dans Google Drive.

# %%
#***********************************FIN******************************************************#
#********************************************************************************************#
#********************************************************************************************#

# %%
# Importer les bibliothèques nécessaires
from pptx import Presentation
import re
import random

# Fonction pour extraire le texte des diapositives
def extract_text_from_pptx(file_path):
    prs = Presentation(file_path)
    text = []
    for slide in prs.slides:
        for shape in slide.shapes:
            if hasattr(shape, 'text'):
                text.append(shape.text)
    return text

# Nettoyage du texte pour l'utiliser dans le modèle RAG
def clean_text(text):
    cleaned_text = []
    for paragraph in text:
        # Retirer les numéros de page, les retours à la ligne inutiles, etc.
        paragraph = paragraph.strip()
        if paragraph:
            # Suppression de ponctuations inutiles et normalisation
            paragraph = re.sub(r'\s+', ' ', paragraph)
            cleaned_text.append(paragraph)
    return cleaned_text

# Générer des questions et réponses basées sur le texte nettoyé
def generate_quiz(text, difficulty_level):
    quiz = []

    # Ici, nous allons simplement générer des questions basées sur les concepts extraits
    for section in text:
        # Exemple de question basée sur la section (vous pouvez ajuster selon le contenu)
        question = f"Quel est le principal concept discuté dans cette section : {section[:50]}?"
        answers = [f"Option A - {section[:30]}", f"Option B - {section[30:60]}", f"Option C - {section[60:90]}", f"Option D - {section[-30:]}"]

        # On simule un choix correct en fonction de la difficulté
        correct_answer = random.choice(answers)

        quiz.append({
            'question': question,
            'answers': answers,
            'correct_answer': correct_answer
        })

    # Retourner les quiz générés
    return quiz

# Afficher le quiz généré pour un niveau de difficulté
def display_quiz(quiz):
    for q in quiz:
        print(f"Question: {q['question']}")
        for ans in q['answers']:
            print(f"  {ans}")
        print(f"Réponse correcte: {q['correct_answer']}\n")

# Charger le fichier PPTX
file_path = "/mnt/data/TW-Formation Métiers.pptx"

# Étape 1: Extraire le texte du fichier PowerPoint
extracted_text = extract_text_from_pptx(file_path)

# Étape 2: Nettoyer le texte
cleaned_text = clean_text(extracted_text)

# Demander à l'utilisateur le niveau de difficulté
difficulty_level = input("Veuillez entrer le niveau de difficulté (facile, moyen, difficile): ").lower()

# Étape 3: Générer des quiz basés sur le texte nettoyé
quiz = generate_quiz(cleaned_text, difficulty_level)

# Étape 4: Afficher le quiz
display_quiz(quiz)

# %%
cleaned_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-39d96c45e277> in <cell line: 0>()
# ----> 1 cleaned_text
#
# NameError: name 'cleaned_text' is not defined

# %%
# Générer des questions et réponses basées sur le texte nettoyé
def generate_quiz(text, difficulty_level):
    quiz = []
    for section in text:
        question = f"Quel est le principal concept discuté dans cette section : {section[:50]}?"
        answers = [f"Option A - {section[:30]}", f"Option B - {section[30:60]}", f"Option C - {section[60:90]}", f"Option D - {section[-30:]}"]
        correct_answer = random.choice(answers)
        quiz.append({
            'question': question,
            'answers': answers,
            'correct_answer': correct_answer
        })
    return quiz
# Afficher le quiz généré
def display_quiz(quiz):
    for q in quiz:
        print(f"Question: {q['question']}")
        for ans in q['answers']:
            print(f"  {ans}")
        print(f"Réponse correcte: {q['correct_answer']}\n")

# Étape 1: Extraire le texte du fichier PowerPoint
extracted_text = extract_text_from_pptx(file_path)

# Étape 2: Nettoyer le texte
cleaned_text = clean_text(extracted_text)

# Demander à l'utilisateur du niveau de difficulté
difficulty_level = input("Veuillez entrer le niveau de difficulté (facile, moyen, difficile): ").lower()

# Étape 3: Générer des quiz basés sur le texte nettoyé
quiz = generate_quiz(cleaned_text, difficulty_level)

# Étape 4: Afficher le quiz
display_quiz(quiz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-448d53cf20ef> in <cell line: 0>()
#      21
#      22 # Étape 1: Extraire le texte du fichier PowerPoint
# ---> 23 extracted_text = extract_text_from_pptx(file_path)
#      24
#      25 # Étape 2: Nettoyer le texte
#
# NameError: name 'extract_text_from_pptx' is not defined

# %%
# 📌 Étape 1 : Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 📌 Étape 2 : Installer les bibliothèques nécessaires
# !pip install python-pptx Pillow pandas tqdm

# 📌 Étape 3 : Importer les bibliothèques
import os
import io
import re
import uuid
import json
import pandas as pd
import numpy as np
from PIL import Image
from pptx import Presentation
from tqdm.notebook import tqdm
from collections import defaultdict

# 📌 Étape 4 : Définir le chemin du fichier et les dossiers de sortie
file_path = "/content/drive/MyDrive/BASE DE CONNAISSANCES/TW-Formation Métiers.pptx"
output_folder = "/content/drive/MyDrive/BASE DE CONNAISSANCES/TW_Formation_Extraite"
images_folder = os.path.join(output_folder, "images")

# Créer les dossiers s'ils n'existent pas
os.makedirs(output_folder, exist_ok=True)
os.makedirs(images_folder, exist_ok=True)

# 📌 Étape 5 : Fonctions d'extraction améliorées

def clean_text(text):
    """Nettoie le texte tout en préservant la structure"""
    # Remplacer les multiples espaces par un seul
    text = re.sub(r'\s+', ' ', text)
    # Retirer les numéros de liste au début d'une ligne
    text = re.sub(r'^\s*\d+[\.\)-]?\s*', '', text)
    # Retirer les caractères spéciaux problématiques
    text = text.replace('\u000b', ' ').replace('\u0007', '')
    return text.strip()

def get_slide_layout_name(slide):
    """Récupère le nom du layout de la slide"""
    try:
        return slide.slide_layout.name
    except:
        return "Unknown Layout"

def get_shape_hierarchy(shape, level=0, max_level=5):
    """Extrait la hiérarchie des formes avec leur niveau d'imbrication"""
    if level > max_level:  # Éviter les récursions infinies
        return []

    result = []
    # Récupérer les données de base de la forme
    if hasattr(shape, "text") and shape.text.strip():
        shape_data = {
            "id": str(uuid.uuid4())[:8],
            "level": level,
            "type": shape.__class__.__name__,
            "text": shape.text.strip(),
            "top": getattr(shape, "top", 0),
            "left": getattr(shape, "left", 0),
            "width": getattr(shape, "width", 0),
            "height": getattr(shape, "height", 0),
            "is_title": getattr(shape, "is_title", False)
        }
        result.append(shape_data)

    # Récupérer les sous-formes si existantes
    if hasattr(shape, "shapes"):
        for subshape in shape.shapes:
            result.extend(get_shape_hierarchy(subshape, level + 1, max_level))

    return result

def extract_slide_text(slide, slide_index):
    """Extrait tout le texte d'une diapositive avec structure hiérarchique"""
    shapes_data = []
    content_blocks = []
    title = ""

    # Récupérer le layout
    layout_name = get_slide_layout_name(slide)

    # Extraire toutes les formes
    for shape_idx, shape in enumerate(slide.shapes):
        hierarchy = get_shape_hierarchy(shape)
        if hierarchy:
            shapes_data.extend(hierarchy)

            # Déterminer si c'est un titre
            for item in hierarchy:
                if item["is_title"] or item["top"] < 100:
                    if not title or len(item["text"]) > len(title):
                        title = item["text"]
                else:
                    # Traiter le texte
                    text_lines = item["text"].split('\n')
                    for line in text_lines:
                        clean_line = clean_text(line)
                        if clean_line:
                            content_blocks.append({
                                "shape_id": item["id"],
                                "text": clean_line,
                                "level": item["level"],
                                "y_position": item["top"]
                            })

    # Si aucun titre n'a été trouvé, essayez de déterminer le meilleur candidat
    if not title and shapes_data:
        top_shapes = sorted(shapes_data, key=lambda x: x["top"])
        if top_shapes:
            title = top_shapes[0]["text"]

    # Trier les blocs de contenu par position verticale
    content_blocks.sort(key=lambda x: (x["y_position"], x["level"]))

    # Construire le contenu structuré
    content = [block["text"] for block in content_blocks]

    return {
        "slide_num": slide_index + 1,
        "layout": layout_name,
        "title": title,
        "content": content,
        "raw_shapes": shapes_data,
        "full_text": " ".join([title] + content) if title else " ".join(content)
    }

def extract_slide_images(slide, slide_index):
    """Extrait toutes les images d'une diapositive"""
    images = []

    for shape_idx, shape in enumerate(slide.shapes):
        if hasattr(shape, "image"):
            try:
                # Extraire l'image
                image_data = shape.image.blob
                image_filename = f"slide_{slide_index+1}_image_{shape_idx+1}.png"
                image_path = os.path.join(images_folder, image_filename)

                # Enregistrer l'image
                with open(image_path, "wb") as f:
                    f.write(image_data)

                # Obtenir les dimensions de l'image
                image = Image.open(io.BytesIO(image_data))
                width, height = image.size

                # Ajouter les métadonnées de l'image
                images.append({
                    "filename": image_filename,
                    "path": image_path,
                    "width": width,
                    "height": height,
                    "position_x": getattr(shape, "left", 0),
                    "position_y": getattr(shape, "top", 0),
                    "shape_width": getattr(shape, "width", 0),
                    "shape_height": getattr(shape, "height", 0)
                })
            except Exception as e:
                print(f"Erreur lors de l'extraction de l'image sur la diapositive {slide_index+1}: {str(e)}")

    return images

def extract_presentation_metadata(prs):
    """Extrait les métadonnées de la présentation"""
    props = prs.core_properties
    return {
        "title": getattr(props, "title", "") or "Titre inconnu",
        "author": getattr(props, "author", "") or "Auteur inconnu",
        "subject": getattr(props, "subject", "") or "",
        "keywords": getattr(props, "keywords", "") or "",
        "created": str(getattr(props, "created", "")),
        "modified": str(getattr(props, "modified", "")),
        "last_modified_by": getattr(props, "last_modified_by", "") or "",
        "revision": getattr(props, "revision", "") or "",
        "slide_count": len(prs.slides),
        "content_status": getattr(props, "content_status", "") or ""
    }

# 📌 Étape 6 : Extraction complète de la présentation
def extract_full_presentation(file_path):
    """Extrait tout le contenu structuré d'une présentation PowerPoint"""
    try:
        print(f"Chargement de la présentation: {file_path}")
        prs = Presentation(file_path)

        # Extraire les métadonnées
        metadata = extract_presentation_metadata(prs)
        print(f"Présentation chargée: {metadata['title']} ({metadata['slide_count']} diapositives)")

        # Préparer les structures de données
        slides_data = []
        all_images = []
        topics = defaultdict(list)

        # Extraire chaque diapositive
        print("Extraction des diapositives en cours...")
        for i, slide in enumerate(tqdm(prs.slides, total=len(prs.slides))):
            # Extraire le texte
            slide_content = extract_slide_text(slide, i)
            slides_data.append(slide_content)

            # Extraire les images
            slide_images = extract_slide_images(slide, i)
            if slide_images:
                slide_content["images"] = slide_images
                all_images.extend(slide_images)

            # Identifier les thèmes potentiels
            if slide_content["title"]:
                topic = slide_content["title"].split(" ")[0] if " " in slide_content["title"] else slide_content["title"]
                topics[topic].append(i + 1)

        # Organiser les résultats
        result = {
            "metadata": metadata,
            "slides": slides_data,
            "topics": [{"name": k, "slides": v} for k, v in topics.items()],
            "image_count": len(all_images),
            "images": all_images
        }

        return result

    except Exception as e:
        print(f"Erreur lors de l'extraction: {str(e)}")
        import traceback
        traceback.print_exc()
        return None

# 📌 Étape 7 : Exécuter l'extraction et sauvegarder les résultats
print("Démarrage de l'extraction complète...")
presentation_data = extract_full_presentation(file_path)

if presentation_data:
    # Sauvegarder les résultats complets en JSON
    json_path = os.path.join(output_folder, "presentation_complete.json")
    with open(json_path, 'w', encoding='utf-8') as f:
        json.dump(presentation_data, f, ensure_ascii=False, indent=2)

    # Créer un DataFrame pour les diapositives
    df_slides = pd.DataFrame([{
        "slide_num": slide["slide_num"],
        "title": slide["title"],
        "content": "\n".join(slide["content"]) if isinstance(slide["content"], list) else slide["content"],
        "layout": slide["layout"],
        "image_count": len(slide.get("images", [])),
        "full_text": slide["full_text"]
    } for slide in presentation_data["slides"]])

    # Sauvegarder le DataFrame en CSV et Excel
    csv_path = os.path.join(output_folder, "slides_content.csv")
    excel_path = os.path.join(output_folder, "slides_content.xlsx")
    df_slides.to_csv(csv_path, index=False)
    df_slides.to_excel(excel_path, index=False)

    # Créer un document texte structuré avec tout le contenu
    text_path = os.path.join(output_folder, "presentation_text.txt")
    with open(text_path, 'w', encoding='utf-8') as f:
        f.write(f"TITRE: {presentation_data['metadata']['title']}\n")
        f.write(f"AUTEUR: {presentation_data['metadata']['author']}\n")
        f.write(f"DATE: {presentation_data['metadata']['created']}\n\n")

        f.write("=" * 80 + "\n\n")

        for slide in presentation_data["slides"]:
            f.write(f"DIAPOSITIVE {slide['slide_num']}: {slide['title']}\n")
            f.write("-" * 80 + "\n")

            if isinstance(slide["content"], list):
                for item in slide["content"]:
                    f.write(f"• {item}\n")
            else:
                f.write(slide["content"])

            if "images" in slide:
                f.write("\nIMAGES:\n")
                for img in slide["images"]:
                    f.write(f"  - {img['filename']}\n")

            f.write("\n" + "=" * 80 + "\n\n")

    print(f"✅ Extraction terminée avec succès!")
    print(f"📊 {len(presentation_data['slides'])} diapositives extraites")
    print(f"🖼️ {presentation_data['image_count']} images extraites")
    print(f"📁 Résultats sauvegardés dans: {output_folder}")
    print(f"📄 Fichiers créés:")
    print(f"   - {json_path}")
    print(f"   - {csv_path}")
    print(f"   - {excel_path}")
    print(f"   - {text_path}")
    print(f"   - Dossier d'images: {images_folder}")
else:
    print("❌ L'extraction a échoué.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: python-pptx in /usr/local/lib/python3.11/dist-packages (1.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (3.2.3)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (5.3.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (4.13.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Démarrage de l'extraction complète...
# Chargement de la présentation: /content/drive/MyDrive/BASE DE CONNAISSANCES/TW-Formation Métiers.pptx
# Présentation chargée: Présentation PowerPoint (54 diapositives)
# Extraction des diapositives en cours...
#   0%|          | 0/54 [00:00<?, ?it/s]
# ✅ Extraction terminée avec succès!
# 📊 54 diapositives extraites
# 🖼️ 29 images extraites
# 📁 Résultats sauvegardés dans: /content/drive/MyDrive/BASE DE CONNAISSANCES/TW_Formation_Extraite
# 📄 Fichiers créés:
#    - /content/drive/MyDrive/BASE DE CONNAISSANCES/TW_Formation_Extraite/presentation_complete.json
#    - /content/drive/MyDrive/BASE DE CONNAISSANCES/TW_Formation_Extraite/slides_content.csv
#    - /content/drive/MyDrive/BASE DE CONNAISSANCES/TW_Formation_Extraite/slides_content.xlsx
#    - /content/drive/MyDrive/BASE DE CONNAISSANCES/TW_Formation_Extraite/presentation_text.txt
#    - Dossier d'images: /content/drive/MyDrive/BASE DE CONNAISSANCES/TW_Formation_Extraite/images
